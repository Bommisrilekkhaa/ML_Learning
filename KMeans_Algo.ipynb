# %% [markdown]
# <a href="https://colab.research.google.com/github/Bommisrilekkhaa/ML/blob/main/KMeans_Algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly as py
import plotly.graph_objs as go
from sklearn.cluster import KMeans

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/Mall_Customers.csv")

# %%
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
x = data.iloc[:,[3,4]].values
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
clust = []

for i in range(1,11):
  kmeans = KMeans(n_clusters= i, init = "k-means++", random_state=0)
  kmeans.fit(x)
  clust.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),clust)
plt.title('The Elbow Method')
plt.xlabel('No.of clusters')
plt.ylabel('clust')
plt.show()

# %%
model = KMeans(n_clusters= i, init = "k-means++", random_state=0)
y_kmeans = model.fit_predict(x)

# %%
plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],s=30,c='red',label='cluster 1',marker="o")
plt.scatter(x[y_kmeans==1,0],x[y_kmeans==1,1],s=30,c='blue',label='cluster 2',marker="o")
plt.scatter(x[y_kmeans==2,0],x[y_kmeans==2,1],s=30,c='green',label='cluster 3',marker="o")
plt.scatter(x[y_kmeans==3,0],x[y_kmeans==3,1],s=30,c='yellow',label='cluster 4',marker="o")
plt.scatter(x[y_kmeans==4,0],x[y_kmeans==4,1],s=30,c='orange',label='cluster 5',marker="o")
plt.scatter(model.cluster_centers_[:,0],model.cluster_centers_[:,1],s=60,c='black',marker ='*',label='centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
